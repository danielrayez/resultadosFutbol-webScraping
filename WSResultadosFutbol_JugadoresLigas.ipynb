# %% [markdown]
# En este proyecto busco extraer algunos datos de interés de los futbolistas que integran las plantillas de los equipos de las ligas de futbol de sudamerica y Europa. Estos datos serán exportados a dos destinos: una hoja de excel y una base de datos en postresql.
#
# En este proyecto trabajaré con las librerias de python: requests, bs4, pandas, sqlachemy y psycopg2
#
# Estos datos formarán parte de la tabla 'jugadores' en la base de datos análisis_futbol en postgresql, donde hare, entre otros, el modelado de datos junto a las tablas 'equipos' y regiones
#
# Posterior a la extracción y transformacion y carga, haré una presentación visual con algunas comparaciones entre ligas en Power Bi

# %%
url = 'https://www.resultados-futbol.com/portugal'

# %%
# import requests
# import time

# %%
inicio =time.time()

# %%
# from bs4 import BeautifulSoup

# %%
# # esta funcion es para obtener los links de cada una de las ligas de futbol de interés
# def obtener_websites_equipos(link_ppal):
#     re = requests.get(link_ppal)
#     sopa = BeautifulSoup(re.text, 'lxml')
#     sopa_equipos_liga = sopa.find('table', attrs= {'id':'tabla2'}).find_all('tr')
#     sopa_equipos_liga.pop(0)
#     links1 = [url.a.get('href') for url in sopa_equipos_liga]
#     links2 = ["https://www.resultados-futbol.com"+url for url in links1]
    
#     return links2

# %%
# # función para extraer los datos de cada jugador de todos los equipos de la liga dada
# def armar_plantilla(link):  
    
    
#     r = requests.get(link)
#     sopa = BeautifulSoup(r.text, 'lxml')
#     ptll_soup = sopa.find_all('tr', attrs= {'itemprop':'employee'})
    
        
#     plantilla = []
#     i = 0
    
#     while i <  len(ptll_soup):
                    
                   
#         print(f"estoy extrayendo los datos del jugador {i}")
        
#                 #equipo
#         e =  sopa.find('div', attrs= {'class':'contentitem bi-info'}).find_all('ul')
#         equi =  e[0].find_all_next('span')
#         equipo =  equi[3].get_text()
        
#                 #posicion
#         posicion = ptll_soup[i].find_previous_sibling('tr', attrs = {'class':'first-child'}).get_text(strip = True)
#                 #nombre
#         nombre = ptll_soup[i].find('span').text
#                #numero
#         numero_jugador = ptll_soup[i].find('td', attrs= {"class":"num"}).text
#                 #fecha_nacimiento
#         nac_jugador = ptll_soup[i].find('td', attrs={'itemprop':"birthDate"}).get('content')[:10]  
#                 #edad
#         edad_jugador = ptll_soup[i].find('td', attrs={'itemprop':"birthDate"}).text
#                 #nacionalidad
#         tag_nacionalidad = ptll_soup[i].find('td', attrs= {'itemprop':'nationality'})
#         str_nacionalidad = str(tag_nacionalidad)
#         nacionalidad = str_nacionalidad[104:106]
#                 #Altura y peso
#         altura_peso = ptll_soup[i].find_all('td', attrs= {'class':'dat'}, limit=2)
#         altura= altura_peso[0].text
#         peso= altura_peso[1].text

#                 #agregar nuevo elemento a la lista
#         plantilla.extend([equipo])
#         plantilla.extend([nombre])
#         plantilla.extend([nac_jugador])
#         plantilla.extend([edad_jugador])
#         plantilla.extend([nacionalidad])
#         plantilla.extend([numero_jugador])
#         plantilla.extend([posicion])
#         plantilla.extend([altura])
#         plantilla.extend([peso])

#         i = i+1
      
#     else:
        
#         return plantilla

# %%
liga = str(url[34:])
liga
# Out:
# 'portugal'

# %%
#aplico función al link de la liga para obtener los links de cada equipo que la conforma
links = obtener_websites_equipos(url)
links
# Out:
# ['https://www.resultados-futbol.com/Benfica',
#  'https://www.resultados-futbol.com/Fc-Porto',
#  'https://www.resultados-futbol.com/Sporting-Braga',
#  'https://www.resultados-futbol.com/Sporting-Lisbon',
#  'https://www.resultados-futbol.com/Casa-Pia',
#  'https://www.resultados-futbol.com/Vitoria-Guimaraes',
#  'https://www.resultados-futbol.com/Portimonense',
#  'https://www.resultados-futbol.com/Arouca',
#  'https://www.resultados-futbol.com/Chaves',
#  'https://www.resultados-futbol.com/Rio-Ave',
#  'https://www.resultados-futbol.com/Boavista',
#  'https://www.resultados-futbol.com/Estoril',
#  'https://www.resultados-futbol.com/Vizela',
#  'https://www.resultados-futbol.com/Santa-Clara',
#  'https://www.resultados-futbol.com/Famalicao',
#  'https://www.resultados-futbol.com/Gil-Vicente',
#  'https://www.resultados-futbol.com/Maritimo',
#  'https://www.resultados-futbol.com/Pacos-Ferreira']

# %%
#lista donde agrego los datos de cada jugador obtenidos con las función "armar_plantilla"
lis = []
for i in links:
    lis.append(armar_plantilla(i))
# Out:
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# ...

# %%
len(lis)
# Out:
# 18

# %%
#hago una (1) lista 
lista = []
i = 0
while i < len(lis):
    l1= lis[i]
    lista.extend(l1)
    i = i +1

# %%
len(lista)
# Out:
# 4833

# %%
# separo la lista en sublistas por jugador
n=9

plantilla_final =[lista[i:i + n] for i in range(0, len(lista), n)]
plantilla_final
# Out:
# [['Sport Lisboa e Benfica',
#   'Helton Leite',
#   '1990-11-02',
#   '32',
#   'BR',
#   '77',
#   'Portero',
#   '196',
#   '90'],
#  ['Sport Lisboa e Benfica',
#   'O. Vlachodimos',
#   '1994-04-26',
#   '28',
#   'GR',
#   '99',
#   'Portero',
#   '191',
#   '73'],
#  ['Sport Lisboa e Benfica',
#   'S. Soares',
#   '2002-06-15',
#   '20',
#   'PT',
#   '24',
#   'Portero',
#   '190',
#   '93'],
#  ['Sport Lisboa e Benfica',
#   'A. Almeida',
#   '1990-09-10',
#   '32',
#   'PT',
#   '34',
#   'Defensa',
#   '186',
#   '75'],
#  ['Sport Lisboa e Benfica',
#   'A. Bah',
#   '1997-12-09',
#   '24',
#   'DK',
#   '6',
#   'Defensa',
#   '183',
#   '76'],
#  ['Sport Lisboa e Benfica',
#   'A. Grimaldo',
#   '1995-09-20',
#   '27',
#   'ES',
#   '3',
#   'Defensa',
#   '170',
#   '67'],
#  ['Sport Lisboa e Benfica',
#   'A. Silva',
#   '2003-10-30',
#   '19',
#   'PT',
#   '66',
#   'Defensa',
#   '187',
#   '80'],
#  ['Sport Lisboa e Benfica',
#   'Gilberto',
#   '1993-03-07',
# ...

# %%
import pandas as pd

# %%
#Expreso como DataFrame
plantillas_df = pd.DataFrame(plantilla_final)
plantillas_df
# Out:
#                                  0               1           2   3   4   5  \
# 0           Sport Lisboa e Benfica    Helton Leite  1990-11-02  32  BR  77
# 1           Sport Lisboa e Benfica  O. Vlachodimos  1994-04-26  28  GR  99
# 2           Sport Lisboa e Benfica       S. Soares  2002-06-15  20  PT  24
# 3           Sport Lisboa e Benfica      A. Almeida  1990-09-10  32  PT  34
# 4           Sport Lisboa e Benfica          A. Bah  1997-12-09  24  DK   6
# ..                             ...             ...         ...  ..  ..  ..
# 532  Fuetbol C. PaÃ§os de Ferreira           Kayky  2003-06-11  19  BR  11
# 533  Fuetbol C. PaÃ§os de Ferreira     Mauro Couto  2005-11-15  17  PT  41
# 534  Fuetbol C. PaÃ§os de Ferreira       N. Thomas  2001-02-01  21  CW   7
# 535  Fuetbol C. PaÃ§os de Ferreira        P. Koffi  2002-03-09  20  FR  19
# 536  Fuetbol C. PaÃ§os de Ferreira      ZÃ© Uilton  1992-07-25  30  BR   9
#
#              6    7   8
# 0      Portero  196  90
# ...

# %%
#Nombro columnas
plantillas_df.columns=['equipo','nombre','fecha_nacimiento','edad', 'nacionalidad','numero','posicion','altura','peso']
plantillas_df
# Out:
#                             equipo          nombre fecha_nacimiento edad  \
# 0           Sport Lisboa e Benfica    Helton Leite       1990-11-02   32
# 1           Sport Lisboa e Benfica  O. Vlachodimos       1994-04-26   28
# 2           Sport Lisboa e Benfica       S. Soares       2002-06-15   20
# 3           Sport Lisboa e Benfica      A. Almeida       1990-09-10   32
# 4           Sport Lisboa e Benfica          A. Bah       1997-12-09   24
# ..                             ...             ...              ...  ...
# 532  Fuetbol C. PaÃ§os de Ferreira           Kayky       2003-06-11   19
# 533  Fuetbol C. PaÃ§os de Ferreira     Mauro Couto       2005-11-15   17
# 534  Fuetbol C. PaÃ§os de Ferreira       N. Thomas       2001-02-01   21
# 535  Fuetbol C. PaÃ§os de Ferreira        P. Koffi       2002-03-09   20
# 536  Fuetbol C. PaÃ§os de Ferreira      ZÃ© Uilton       1992-07-25   30
#
#     nacionalidad numero   posicion altura peso
# ...

# %%
# #cantidad de jugadores en la liga
# l = len(plantillas_df)
# l

# %%
#Agrego nueva columna que contiene id del jugador
plantillas_df['id_jugador'] = plantillas_df['nombre']+'-'+plantillas_df['fecha_nacimiento']+'-'+plantillas_df['nacionalidad']
plantillas_df = plantillas_df.reindex(columns=['id_jugador','equipo','nombre','fecha_nacimiento','edad', 
                                            'nacionalidad','numero','posicion','altura','peso'])

# %%
plantillas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_jugador        537 non-null    object
#  1   equipo            537 non-null    object
#  2   nombre            537 non-null    object
#  3   fecha_nacimiento  537 non-null    object
#  4   edad              537 non-null    object
#  5   nacionalidad      537 non-null    object
#  6   numero            537 non-null    object
#  7   posicion          537 non-null    object
#  8   altura            537 non-null    object
#  9   peso              537 non-null    object
# dtypes: object(10)
# memory usage: 42.1+ KB

# %%
#cambio tipo de datos
plantillas_df['altura'] = pd.to_numeric(plantillas_df['altura'], errors= 'coerce')
plantillas_df['peso'] = pd.to_numeric(plantillas_df['peso'], errors= 'coerce')
plantillas_df['edad'] = pd.to_numeric(plantillas_df['edad'], errors= 'coerce')

# %%
plantillas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_jugador        537 non-null    object
#  1   equipo            537 non-null    object
#  2   nombre            537 non-null    object
#  3   fecha_nacimiento  537 non-null    object
#  4   edad              537 non-null    int64
#  5   nacionalidad      537 non-null    object
#  6   numero            537 non-null    object
#  7   posicion          537 non-null    object
#  8   altura            524 non-null    float64
#  9   peso              504 non-null    float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 42.1+ KB

# %%
# #Exporto a Exel
# with pd.ExcelWriter('plantillas-ligas-jugadores2022-2.xlsx', mode='a', engine ='openpyxl') as writer:
#     plantillas_df.to_excel(writer, sheet_name= liga)

# %%
plantillas_df.to_csv('plantillas-ligas-jugadores2022-2.csv', encoding='utf=8', index=False, mode='a')

# %%
#Exporto a SQL

# %%
# pip install psycopg2

# %%
# from sqlalchemy import create_engine

# %%
cadena_conexion = 'postgres+psycopg2://postgres:2511@localhost:5432/Analisis_futbol'
engine = create_engine(cadena_conexion)

# %%
plantillas_df.to_sql('jugadores',con=engine, if_exists= 'append', index=False )

# %%
fin = time.time()
tiempo = inicio-fin

# %%
tiempo
# Out:
# -53.10254764556885
