# %% [markdown]
# En este proyecto busco extraer algunos datos de interés de los futbolistas que integran las plantillas de los equipos de las ligas de futbol de sudamerica y Europa. Estos datos serán exportados a dos destinos: una hoja de excel y una base de datos en postresql.
#
# En este proyecto trabajaré con las librerias de python: requests, bs4, pandas, sqlachemy y psycopg2
#
# Estos datos formarán parte de la tabla 'jugadores' en la base de datos análisis_futbol en postgresql, donde hare, entre otros, el modelado de datos junto a las tablas 'equipos' y regiones
#
# Posterior a la extracción y transformacion y carga, haré una presentación visual con algunas comparaciones entre ligas en Power Bi

# %%
url = 'https://www.resultados-futbol.com/primera_chile_liga_unica'

# %%
import requests

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\danie\anaconda3\lib\site-packages (4.8.2)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\danie\anaconda3\lib\site-packages (from beautifulsoup4) (1.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
# esta funcion es para obtener los links de cada una de las ligas de futbol de interés
def obtener_websites_equipos(link_ppal):
    re = requests.get(link_ppal)
    sopa = BeautifulSoup(re.text, 'lxml')
    sopa_equipos_liga = sopa.find('table', attrs= {'id':'tabla2'}).find_all('tr')
    sopa_equipos_liga.pop(0)
    links1 = [url.a.get('href') for url in sopa_equipos_liga]
    links2 = ["https://www.resultados-futbol.com"+url for url in links1]
    return links2

# %%
# función para extraer los datos de cada jugador de todos los equipos de la liga dada
def armar_plantilla(link):  
    
    
    r = requests.get(link)
    sopa = BeautifulSoup(r.text, 'lxml')
    ptll_soup = sopa.find_all('tr', attrs= {'itemprop':'employee'})
    
        
    plantilla = []
    i = 0
    
    while i <  len(ptll_soup):
                    
                   
        print(f"estoy extrayendo los datos del jugador {i}")
        
                #equipo
        e =  sopa.find('div', attrs= {'class':'contentitem bi-info'}).find_all('ul')
        equi =  e[0].find_all_next('span')
        equipo =  equi[3].get_text()
        
                #posicion
        posicion = ptll_soup[i].find_previous_sibling('tr', attrs = {'class':'first-child'}).get_text(strip = True)
                #nombre
        nombre = ptll_soup[i].find('span').text
               #numero
        numero_jugador = ptll_soup[i].find('td', attrs= {"class":"num"}).text
                #edad
        edad_jugador = ptll_soup[i].find('td', attrs={'itemprop':"birthDate"}).text
                #nacionalidad
        tag_nacionalidad = ptll_soup[i].find('td', attrs= {'itemprop':'nationality'})
        str_nacionalidad = str(tag_nacionalidad)
        nacionalidad = str_nacionalidad[104:106]
                #Altura y peso
        altura_peso = ptll_soup[i].find_all('td', attrs= {'class':'dat'}, limit=2)
        altura= altura_peso[0].text
        peso= altura_peso[1].text

                #agregar nuevo elemento a la lista
        plantilla.extend([equipo])
        plantilla.extend([nombre])
        plantilla.extend([edad_jugador])
        plantilla.extend([nacionalidad])
        plantilla.extend([numero_jugador])
        plantilla.extend([posicion])
        plantilla.extend([altura])
        plantilla.extend([peso])

        i = i+1
        
    else:
        
        return plantilla

# %%
liga = str(url[34:])
liga
# Out:
# 'primera_chile_liga_unica'

# %%
#aplico función al link de la liga para obtener los links de cada equipo que la conforma
links = obtener_websites_equipos(url)

# %%
links
# Out:
# ['https://www.resultados-futbol.com/Colo-Colo/2022',
#  'https://www.resultados-futbol.com/Curico-Unido/2022',
#  'https://www.resultados-futbol.com/Nublense/2022',
#  'https://www.resultados-futbol.com/Audax-Italiano/2022',
#  'https://www.resultados-futbol.com/Cobresal/2022',
#  'https://www.resultados-futbol.com/Everton/2022',
#  'https://www.resultados-futbol.com/Univ-Catolica/2022',
#  'https://www.resultados-futbol.com/O-Higgins/2022',
#  'https://www.resultados-futbol.com/Union-Espanola/2022',
#  'https://www.resultados-futbol.com/Palestino/2022',
#  'https://www.resultados-futbol.com/Union-Calera/2022',
#  'https://www.resultados-futbol.com/Huachipato/2022',
#  'https://www.resultados-futbol.com/Universidad-Chile/2022',
#  'https://www.resultados-futbol.com/Cd-Serena/2022',
#  'https://www.resultados-futbol.com/Antofagasta/2022',
#  'https://www.resultados-futbol.com/Coquimbo-Unido/2022']

# %%
#lista donde agrego los datos de cada jugador obtenidos con las función "armar_plantilla"
lis = []
for i in links:
    lis.append(armar_plantilla(i))
# Out:
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 32
# estoy extrayendo los datos del jugador 33
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30
# estoy extrayendo los datos del jugador 31
# estoy extrayendo los datos del jugador 32
# estoy extrayendo los datos del jugador 33
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 0
# estoy extrayendo los datos del jugador 1
# estoy extrayendo los datos del jugador 2
# estoy extrayendo los datos del jugador 3
# estoy extrayendo los datos del jugador 4
# estoy extrayendo los datos del jugador 5
# estoy extrayendo los datos del jugador 6
# estoy extrayendo los datos del jugador 7
# estoy extrayendo los datos del jugador 8
# estoy extrayendo los datos del jugador 9
# estoy extrayendo los datos del jugador 10
# estoy extrayendo los datos del jugador 11
# estoy extrayendo los datos del jugador 12
# estoy extrayendo los datos del jugador 13
# estoy extrayendo los datos del jugador 14
# estoy extrayendo los datos del jugador 15
# estoy extrayendo los datos del jugador 16
# estoy extrayendo los datos del jugador 17
# estoy extrayendo los datos del jugador 18
# estoy extrayendo los datos del jugador 19
# estoy extrayendo los datos del jugador 20
# estoy extrayendo los datos del jugador 21
# estoy extrayendo los datos del jugador 22
# estoy extrayendo los datos del jugador 23
# estoy extrayendo los datos del jugador 24
# estoy extrayendo los datos del jugador 25
# estoy extrayendo los datos del jugador 26
# estoy extrayendo los datos del jugador 27
# estoy extrayendo los datos del jugador 28
# estoy extrayendo los datos del jugador 29
# estoy extrayendo los datos del jugador 30

# %%
len(lis)
# Out:
# 16

# %%
#hago una (1) lista con todos los datos
lista = []
i = 0
while i < len(lis):
    l1= lis[i]
    lista.extend(l1)
    i = i +1

# %%
l= len(lista)
l
# Out:
# 3872

# %%
#lista

# %%
# separo la lista en sublistas por jugador
n=8

plantilla_final =[lista[i:i + n] for i in range(0, l, n)]
plantilla_final
# Out:
# [['Club Social y Deportivo Colo-Colo',
#   'B. CortÃ©s',
#   '27',
#   'CL',
#   '1',
#   'Portero',
#   '186',
#   '75'],
#  ['Club Social y Deportivo Colo-Colo',
#   'J. Fierro',
#   '20',
#   'CL',
#   '25',
#   'Portero',
#   '183',
#   '84'],
#  ['Club Social y Deportivo Colo-Colo',
#   'O. CarabalÃ\xad',
#   '25',
#   'CL',
#   '12',
#   'Portero',
#   '186',
#   '84'],
#  ['Club Social y Deportivo Colo-Colo',
#   'B. GutiÃ©rrez',
#   '20',
#   'CL',
#   '13',
#   'Defensa',
#   '184',
#   '65'],
#  ['Club Social y Deportivo Colo-Colo',
#   'D. GutiÃ©rrez',
#   '19',
#   'CL',
#   '3',
#   'Defensa',
#   '176',
#   '70'],
#  ['Club Social y Deportivo Colo-Colo',
#   'E. Amor',
#   '27',
#   'AR',
#   '15',
#   'Defensa',
#   '190',
#   '81'],
#  ['Club Social y Deportivo Colo-Colo',
#   'G. Suazo',
#   '25',
#   'CL',
#   '17',
#   'Defensa',
#   '175',
#   '67'],
#  ['Club Social y Deportivo Colo-Colo',
#   'Jeyson Rojas',
#   '20',
#   'CL',
#   '2',
#   'Defensa',
#   '185',
#   '73'],
#  ['Club Social y Deportivo Colo-Colo',
#   'M. FalcÃ³n',
#   '25',
#   'UY',
#   '37',
#   'Defensa',
#   '179',
#   '80'],
#  ['Club Social y Deportivo Colo-Colo',
#   'M. Zaldivia',
#   '31',
#   'AR',
#   '4',
#   'Defensa',
#   '185',
#   '79'],
#  ['Club Social y Deportivo Colo-Colo',
#   'O. Opazo',
#   '31',
#   'CL',
#   '16',
#   'Defensa',
#   '168',
#   '68'],
#  ['Club Social y Deportivo Colo-Colo',
#   'C. Fuentes',
#   '29',
#   'CL',
#   '6',
#   'Centrocampista',
#   '170',
#   '74'],
#  ['Club Social y Deportivo Colo-Colo',
#   'C. Villanueva',
#   '23',
#   'CL',
#   '26',
#   'Centrocampista',
#   '171',
#   '68'],
#  ['Club Social y Deportivo Colo-Colo',
#   'E. PÃ¡vez',
#   '32',
#   'CL',
#   '23',
#   'Centrocampista',
#   '180',
#   '76'],
#  ['Club Social y Deportivo Colo-Colo',
#   'G. Costa',
#   '32',
#   'PE',
#   '8',
#   'Centrocampista',
#   '172',
#   '72'],
#  ['Club Social y Deportivo Colo-Colo',
#   'L. Gil',
#   '31',
#   'CL',
#   '5',
#   'Centrocampista',
#   '176',
#   '65'],
#  ['Club Social y Deportivo Colo-Colo',
#   'V. Pizarro',
#   '19',
#   'CL',
#   '34',
#   'Centrocampista',
#   '172',
#   '68'],
#  ['Club Social y Deportivo Colo-Colo',
#   'A. Oroz',
#   '19',
#   'CL',
#   '20',
#   'Delantero',
#   '169',
#   '62'],
#  ['Club Social y Deportivo Colo-Colo',
#   'C. Santos',
#   '34',
#   'VE',
#   '10',
#   'Delantero',
#   '184',
#   '70'],
#  ['Club Social y Deportivo Colo-Colo',
#   'C. Zavala',
#   '23',
#   'CL',
#   '14',
#   'Delantero',
#   '173',
#   '-'],
#  ['Club Social y Deportivo Colo-Colo',
#   'J. Lucero',
#   '30',
#   'AR',
#   '9',
#   'Delantero',
#   '181',
#   '71'],
#  ['Club Social y Deportivo Colo-Colo',
#   'Joan Cruz',
#   '19',
#   'CL',
#   '35',
#   'Delantero',
#   '168',
#   '64'],
#  ['Club Social y Deportivo Colo-Colo',
#   'L. Arriagada',
#   '20',
#   'CL',
#   '32',
#   'Delantero',
#   '184',
#   '75'],
#  ['Club Social y Deportivo Colo-Colo',
#   'M. Bolados',
#   '26',
#   'CL',
#   '11',
#   'Delantero',
#   '177',
#   '70'],
#  ['Club Social y Deportivo Colo-Colo',
#   'Pablo Solari',
#   '21',
#   'AR',
#   '36',
#   'Delantero',
#   '181',
#   '75'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'F. Cerda',
#   '33',
#   'CL',
#   '12',
#   'Portero',
#   '183',
#   '83'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'L. Santelices',
#   '36',
#   'CL',
#   '30',
#   'Portero',
#   '183',
#   '77'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'T. Vergara',
#   '20',
#   'CL',
#   '1',
#   'Portero',
#   '182',
#   '75'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'Alexander Del RÃ\xado',
#   '20',
#   'CL',
#   '',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'F. Bechtholdt',
#   '29',
#   'AR',
#   '16',
#   'Defensa',
#   '171',
#   '73'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'J. Gomez',
#   '31',
#   'AR',
#   '15',
#   'Defensa',
#   '182',
#   '81'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'J. Rojas',
#   '39',
#   'CL',
#   '13',
#   'Defensa',
#   '176',
#   '75'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'M. Cahais',
#   '34',
#   'AR',
#   '3',
#   'Defensa',
#   '185',
#   '80'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'M. OrmazÃ¡bal',
#   '24',
#   'CL',
#   '21',
#   'Defensa',
#   '178',
#   '76'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'R. De La Fuente',
#   '31',
#   'CL',
#   '19',
#   'Defensa',
#   '176',
#   '71'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'Y. Opazo',
#   '37',
#   'CL',
#   '32',
#   'Defensa',
#   '172',
#   '66'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'A. Nadruz',
#   '26',
#   'UY',
#   '5',
#   'Centrocampista',
#   '180',
#   '70'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'C. Herrera',
#   '22',
#   'CL',
#   '',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'D. UrzÃºa',
#   '25',
#   'CL',
#   '6',
#   'Centrocampista',
#   '173',
#   '70'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'F. Ortiz',
#   '21',
#   'CL',
#   '18',
#   'Centrocampista',
#   '172',
#   '66'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'J. Gutierrez',
#   '20',
#   'CL',
#   '28',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'M. CortÃ©s',
#   '39',
#   'AR',
#   '17',
#   'Centrocampista',
#   '165',
#   '65'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'M. Sandoval',
#   '31',
#   'CL',
#   '8',
#   'Centrocampista',
#   '165',
#   '68'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'P. Corral',
#   '30',
#   'CL',
#   '23',
#   'Centrocampista',
#   '170',
#   '64'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'R. Albornoz',
#   '20',
#   'CL',
#   '25',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'Y. Leiva',
#   '24',
#   'CL',
#   '10',
#   'Centrocampista',
#   '166',
#   '63'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'B. Oyarzo',
#   '27',
#   'CL',
#   '11',
#   'Delantero',
#   '165',
#   '61'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'C. Bustamante',
#   '20',
#   'CL',
#   '34',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'D. Coelho',
#   '27',
#   'UY',
#   '27',
#   'Delantero',
#   '182',
#   '81'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'F. Fritz',
#   '25',
#   'CL',
#   '7',
#   'Delantero',
#   '180',
#   '73'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'Federico Castro',
#   '29',
#   'AR',
#   '20',
#   'Delantero',
#   '183',
#   '78'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'Ian Aliaga',
#   '20',
#   'CL',
#   '33',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'J. Gonzalez',
#   '21',
#   'CL',
#   '14',
#   'Delantero',
#   '180',
#   '76'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'N. Barrios',
#   '19',
#   'CL',
#   '35',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes Provincial CuricÃ³ Unido',
#   'R. Holgado',
#   '27',
#   'AR',
#   '9',
#   'Delantero',
#   '175',
#   '72'],
#  ['Club Deportivo Ã\x91ublense',
#   'C. Chandia',
#   '-',
#   'CL',
#   '40',
#   'Portero',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'G. Guajardo',
#   '20',
#   'CL',
#   '32',
#   'Portero',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'H. MuÃ±oz',
#   '34',
#   'CL',
#   '25',
#   'Portero',
#   '182',
#   '82'],
#  ['Club Deportivo Ã\x91ublense',
#   'N. PÃ©rez',
#   '32',
#   'UY',
#   '1',
#   'Portero',
#   '184',
#   '80'],
#  ['Club Deportivo Ã\x91ublense',
#   'B. Cerezo',
#   '27',
#   'CL',
#   '18',
#   'Defensa',
#   '170',
#   '68'],
#  ['Club Deportivo Ã\x91ublense',
#   'E. Guerrero',
#   '31',
#   'CL',
#   '17',
#   'Defensa',
#   '181',
#   '80'],
#  ['Club Deportivo Ã\x91ublense',
#   'G. Campusano',
#   '29',
#   'CL',
#   '14',
#   'Defensa',
#   '170',
#   '70'],
#  ['Club Deportivo Ã\x91ublense',
#   'J. Turra',
#   '21',
#   'CL',
#   '3',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'N. Kimura',
#   '25',
#   'CL',
#   '23',
#   'Defensa',
#   '175',
#   '75'],
#  ['Club Deportivo Ã\x91ublense',
#   'N. Mancilla',
#   '29',
#   'CL',
#   '4',
#   'Defensa',
#   '179',
#   '70'],
#  ['Club Deportivo Ã\x91ublense',
#   'P. Vargas',
#   '29',
#   'CL',
#   '8',
#   'Defensa',
#   '175',
#   '70'],
#  ['Club Deportivo Ã\x91ublense',
#   'B. Provoste',
#   '22',
#   'CL',
#   '10',
#   'Centrocampista',
#   '177',
#   '68'],
#  ['Club Deportivo Ã\x91ublense',
#   'C. Meza',
#   '18',
#   'CL',
#   '',
#   'Centrocampista',
#   '170',
#   '70'],
#  ['Club Deportivo Ã\x91ublense',
#   'F. Cordero',
#   '35',
#   'CL',
#   '11',
#   'Centrocampista',
#   '172',
#   '71'],
#  ['Club Deportivo Ã\x91ublense',
#   'F. Mateos',
#   '29',
#   'AR',
#   '20',
#   'Centrocampista',
#   '177',
#   '71'],
#  ['Club Deportivo Ã\x91ublense',
#   'I. Rozas',
#   '24',
#   'CL',
#   '21',
#   'Centrocampista',
#   '180',
#   '79'],
#  ['Club Deportivo Ã\x91ublense',
#   'L. Reyes',
#   '31',
#   'CL',
#   '6',
#   'Centrocampista',
#   '176',
#   '76'],
#  ['Club Deportivo Ã\x91ublense',
#   'M. Rivera',
#   '26',
#   'CL',
#   '28',
#   'Centrocampista',
#   '179',
#   '76'],
#  ['Club Deportivo Ã\x91ublense',
#   'R. Caroca',
#   '33',
#   'CL',
#   '5',
#   'Centrocampista',
#   '173',
#   '74'],
#  ['Club Deportivo Ã\x91ublense',
#   'Rodrigo Cisterna',
#   '20',
#   'CL',
#   '22',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'V. Demateis',
#   '21',
#   'AR',
#   '33',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'W. MartÃ\xadnez',
#   '22',
#   'CL',
#   '13',
#   'Centrocampista',
#   '174',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'A. Aravena',
#   '20',
#   'CL',
#   '16',
#   'Delantero',
#   '174',
#   '70'],
#  ['Club Deportivo Ã\x91ublense',
#   'Bastian Sagal',
#   '23',
#   'MX',
#   '29',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'F. Reynero',
#   '33',
#   'CL',
#   '7',
#   'Delantero',
#   '180',
#   '78'],
#  ['Club Deportivo Ã\x91ublense',
#   'M. Moya',
#   '24',
#   'AR',
#   '30',
#   'Delantero',
#   '167',
#   '67'],
#  ['Club Deportivo Ã\x91ublense',
#   'M. Pinto',
#   '24',
#   'CL',
#   '27',
#   'Delantero',
#   '166',
#   '65'],
#  ['Club Deportivo Ã\x91ublense',
#   'M. Torrealba',
#   '20',
#   'CL',
#   '37',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club Deportivo Ã\x91ublense',
#   'N. Guerra',
#   '23',
#   'CL',
#   '9',
#   'Delantero',
#   '176',
#   '76'],
#  ['Club Deportivo Ã\x91ublense',
#   'P. Rubio',
#   '33',
#   'CL',
#   '12',
#   'Delantero',
#   '178',
#   '72'],
#  ['Audax Italiano La Florida',
#   'Ã\x81. Salazar',
#   '29',
#   'CL',
#   '13',
#   'Portero',
#   '185',
#   '79'],
#  ['Audax Italiano La Florida',
#   'J. GarcÃ\xada',
#   '23',
#   'CL',
#   '',
#   'Portero',
#   '182',
#   '78'],
#  ['Audax Italiano La Florida',
#   'J. MuÃ±oz',
#   '31',
#   'CL',
#   '1',
#   'Portero',
#   '181',
#   '82'],
#  ['Audax Italiano La Florida',
#   'M. Alvarez',
#   '21',
#   'CL',
#   '32',
#   'Portero',
#   '-',
#   '-'],
#  ['Audax Italiano La Florida',
#   'T. Ahumada',
#   '21',
#   'CL',
#   '12',
#   'Portero',
#   '181',
#   '74'],
#  ['Audax Italiano La Florida',
#   'C. LabrÃ\xadn',
#   '31',
#   'CL',
#   '2',
#   'Defensa',
#   '181',
#   '81'],
#  ['Audax Italiano La Florida',
#   'C. MuÃ±oz',
#   '23',
#   'CL',
#   '3',
#   'Defensa',
#   '184',
#   '75'],
#  ['Audax Italiano La Florida',
#   'D. PiÃ±a',
#   '20',
#   'CL',
#   '26',
#   'Defensa',
#   '189',
#   '80'],
#  ['Audax Italiano La Florida',
#   'D. Torres',
#   '30',
#   'CL',
#   '6',
#   'Defensa',
#   '175',
#   '70'],
#  ['Audax Italiano La Florida',
#   'F. Torres',
#   '33',
#   'CL',
#   '5',
#   'Defensa',
#   '180',
#   '78'],
#  ['Audax Italiano La Florida',
#   'N. FernÃ¡ndez',
#   '23',
#   'CL',
#   '7',
#   'Defensa',
#   '170',
#   '66'],
#  ['Audax Italiano La Florida',
#   'O. Bosso',
#   '29',
#   'CL',
#   '4',
#   'Defensa',
#   '177',
#   '64'],
#  ['Audax Italiano La Florida',
#   'O. Rojas',
#   '22',
#   'CL',
#   '16',
#   'Defensa',
#   '179',
#   '68'],
#  ['Audax Italiano La Florida',
#   'P. Alvarado',
#   '36',
#   'AR',
#   '32',
#   'Defensa',
#   '180',
#   '70'],
#  ['Audax Italiano La Florida',
#   'R. Cereceda',
#   '38',
#   'CL',
#   '28',
#   'Defensa',
#   '175',
#   '70'],
#  ['Audax Italiano La Florida',
#   'R. Osorio',
#   '27',
#   'CL',
#   '15',
#   'Defensa',
#   '177',
#   '74'],
#  ['Audax Italiano La Florida',
#   'A. Canales',
#   '22',
#   'CL',
#   '22',
#   'Centrocampista',
#   '189',
#   '73'],
#  ['Audax Italiano La Florida',
#   'E. Matus',
#   '20',
#   'CL',
#   '24',
#   'Centrocampista',
#   '170',
#   '65'],
#  ['Audax Italiano La Florida',
#   'F. Cornejo',
#   '26',
#   'CL',
#   '8',
#   'Centrocampista',
#   '174',
#   '69'],
#  ['Audax Italiano La Florida',
#   'I. Godoy',
#   '19',
#   'CL',
#   '39',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Audax Italiano La Florida',
#   'J. HenrÃ\xadquez',
#   '28',
#   'CL',
#   '10',
#   'Centrocampista',
#   '168',
#   '76'],
#  ['Audax Italiano La Florida',
#   'J. QuiÃ±ones',
#   '20',
#   'CL',
#   '30',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Audax Italiano La Florida',
#   'M. Carrasco',
#   '19',
#   'CL',
#   '23',
#   'Centrocampista',
#   '184',
#   '74'],
#  ['Audax Italiano La Florida',
#   'M. SepÃºlveda',
#   '23',
#   'CL',
#   '19',
#   'Centrocampista',
#   '178',
#   '74'],
#  ['Audax Italiano La Florida',
#   'N. Aedo',
#   '21',
#   'CL',
#   '20',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Audax Italiano La Florida',
#   'T. Andrade',
#   '25',
#   'AR',
#   '35',
#   'Centrocampista',
#   '175',
#   '70'],
#  ['Audax Italiano La Florida',
#   'B. Figueroa',
#   '23',
#   'CL',
#   '17',
#   'Delantero',
#   '180',
#   '69'],
#  ['Audax Italiano La Florida',
#   'G. Ã\x81lvarez',
#   '25',
#   'CL',
#   '14',
#   'Delantero',
#   '170',
#   '68'],
#  ['Audax Italiano La Florida',
#   'G. Estigarribia',
#   '25',
#   'AR',
#   '21',
#   'Delantero',
#   '180',
#   '72'],
#  ['Audax Italiano La Florida',
#   'I. Colombini',
#   '30',
#   'AR',
#   '9',
#   'Delantero',
#   '173',
#   '77'],
#  ['Audax Italiano La Florida',
#   'L. Riveros',
#   '24',
#   'PY',
#   '11',
#   'Delantero',
#   '178',
#   '73'],
#  ['Audax Italiano La Florida',
#   'M. Fuentes',
#   '24',
#   'CL',
#   '27',
#   'Delantero',
#   '177',
#   '-'],
#  ['Audax Italiano La Florida',
#   'Massami GutiÃ©rrez',
#   '19',
#   'CL',
#   '29',
#   'Delantero',
#   '-',
#   '-'],
#  ['Audax Italiano La Florida', 'J. Saavedra', '-', 'CH', '38', '', '-', '-'],
#  ['Club de Deportes Cobresal',
#   'A. Santander',
#   '19',
#   'CL',
#   '12',
#   'Portero',
#   '177',
#   '75'],
#  ['Club de Deportes Cobresal',
#   'J. Deschamps',
#   '38',
#   'CL',
#   '1',
#   'Portero',
#   '183',
#   '77'],
#  ['Club de Deportes Cobresal',
#   'L. Requena',
#   '35',
#   'AR',
#   '22',
#   'Portero',
#   '185',
#   '80'],
#  ['Club de Deportes Cobresal',
#   'BenjamÃ\xadn Romo',
#   '19',
#   'CL',
#   '',
#   'Defensa',
#   '184',
#   '76'],
#  ['Club de Deportes Cobresal',
#   'D. CÃ©spedes',
#   '24',
#   'CL',
#   '28',
#   'Defensa',
#   '181',
#   '68'],
#  ['Club de Deportes Cobresal',
#   'G. Pacheco',
#   '33',
#   'CL',
#   '23',
#   'Defensa',
#   '179',
#   '73'],
#  ['Club de Deportes Cobresal',
#   'I. Contreras',
#   '21',
#   'CL',
#   '4',
#   'Defensa',
#   '175',
#   '78'],
#  ['Club de Deportes Cobresal',
#   'I. Villalba',
#   '27',
#   'PY',
#   '3',
#   'Defensa',
#   '182',
#   '84'],
#  ['Club de Deportes Cobresal',
#   'M. Jorquera',
#   '30',
#   'CL',
#   '7',
#   'Defensa',
#   '175',
#   '71'],
#  ['Club de Deportes Cobresal',
#   'P. CÃ¡rdenas',
#   '22',
#   'CL',
#   '17',
#   'Defensa',
#   '177',
#   '72'],
#  ['Club de Deportes Cobresal',
#   'S. Silva',
#   '31',
#   'CL',
#   '26',
#   'Defensa',
#   '177',
#   '73'],
#  ['Club de Deportes Cobresal',
#   'A. Camargo',
#   '33',
#   'AR',
#   '6',
#   'Centrocampista',
#   '175',
#   '68'],
#  ['Club de Deportes Cobresal',
#   'C. MesÃ\xadas',
#   '24',
#   'CL',
#   '13',
#   'Centrocampista',
#   '180',
#   '77'],
#  ['Club de Deportes Cobresal',
#   'F. AlarcÃ³n',
#   '32',
#   'CL',
#   '5',
#   'Centrocampista',
#   '189',
#   '84'],
#  ['Club de Deportes Cobresal',
#   'F. Valdes',
#   '20',
#   'CL',
#   '8',
#   'Centrocampista',
#   '172',
#   '74'],
#  ['Club de Deportes Cobresal',
#   'L. VÃ¡squez',
#   '20',
#   'CL',
#   '25',
#   'Centrocampista',
#   '167',
#   '60'],
#  ['Club de Deportes Cobresal',
#   'M. Gonzalez',
#   '26',
#   'AR',
#   '19',
#   'Centrocampista',
#   '178',
#   '75'],
#  ['Club de Deportes Cobresal',
#   'MatÃ\xadas AndrÃ©s Fredes Morales',
#   '20',
#   'CL',
#   '',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes Cobresal',
#   'N. SepÃºlveda',
#   '30',
#   'CL',
#   '20',
#   'Centrocampista',
#   '167',
#   '68'],
#  ['Club de Deportes Cobresal',
#   'Y. Cruz',
#   '18',
#   'CL',
#   '24',
#   'Centrocampista',
#   '161',
#   '60'],
#  ['Club de Deportes Cobresal',
#   'B. Osses',
#   '20',
#   'CL',
#   '21',
#   'Delantero',
#   '172',
#   '71'],
#  ['Club de Deportes Cobresal',
#   'C. Munder',
#   '22',
#   'CL',
#   '18',
#   'Delantero',
#   '165',
#   '62'],
#  ['Club de Deportes Cobresal',
#   'C. Waterman',
#   '31',
#   'PA',
#   '30',
#   'Delantero',
#   '181',
#   '73'],
#  ['Club de Deportes Cobresal',
#   'G. Lezcano',
#   '35',
#   'AR',
#   '11',
#   'Delantero',
#   '168',
#   '65'],
#  ['Club de Deportes Cobresal',
#   'J. Gaete',
#   '25',
#   'CL',
#   '10',
#   'Delantero',
#   '175',
#   '71'],
#  ['Club de Deportes Cobresal',
#   'J. Riascos',
#   '21',
#   'CO',
#   '',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes Cobresal',
#   'M. Pol',
#   '34',
#   'AR',
#   '9',
#   'Delantero',
#   '175',
#   '74'],
#  ['Club de Deportes Cobresal',
#   'O. Salinas',
#   '34',
#   'CL',
#   '29',
#   'Delantero',
#   '173',
#   '71'],
#  ['Club de Deportes Cobresal',
#   'S. Carrasco',
#   '17',
#   'CL',
#   '15',
#   'Delantero',
#   '-',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'E. Kirkman',
#   '20',
#   'CL',
#   '31',
#   'Portero',
#   '184',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'F. De Paul',
#   '31',
#   'CL',
#   '30',
#   'Portero',
#   '183',
#   '84'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'F. Torgnascioli',
#   '32',
#   'UY',
#   '1',
#   'Portero',
#   '186',
#   '78'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'J. PeÃ±a',
#   '22',
#   'CL',
#   '12',
#   'Portero',
#   '185',
#   '82'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'A. Ibacache',
#   '23',
#   'CL',
#   '4',
#   'Defensa',
#   '175',
#   '72'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'C. Medina',
#   '21',
#   'CL',
#   '14',
#   'Defensa',
#   '172',
#   '70'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'C. Riquelme',
#   '19',
#   'CL',
#   '2',
#   'Defensa',
#   '173',
#   '64'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'D. OyarzÃºn',
#   '29',
#   'CL',
#   '24',
#   'Defensa',
#   '185',
#   '78'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'F. Campos',
#   '28',
#   'CL',
#   '3',
#   'Defensa',
#   '179',
#   '79'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'J. Barroso',
#   '37',
#   'AR',
#   '5',
#   'Defensa',
#   '175',
#   '71'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'J. Salas',
#   '26',
#   'CL',
#   '22',
#   'Defensa',
#   '173',
#   '68'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'JoaquÃ\xadn LÃ³pez',
#   '23',
#   'CL',
#   '28',
#   'Defensa',
#   '-',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'SebastiÃ¡n Pereira',
#   '23',
#   'CL',
#   '26',
#   'Defensa',
#   '185',
#   '82'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'Ã\x81. Madrid',
#   '27',
#   'CL',
#   '6',
#   'Centrocampista',
#   '180',
#   '74'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'AdriÃ¡n SÃ¡nchez',
#   '23',
#   'AR',
#   '16',
#   'Centrocampista',
#   '178',
#   '72'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'B. BerrÃ\xados',
#   '24',
#   'CL',
#   '21',
#   'Centrocampista',
#   '168',
#   '65'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'C. Valenzuela',
#   '30',
#   'CL',
#   '8',
#   'Centrocampista',
#   '163',
#   '60'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'E. Arismendi',
#   '20',
#   'CL',
#   '29',
#   'Centrocampista',
#   '177',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'F. Saavedra',
#   '36',
#   'CL',
#   '23',
#   'Centrocampista',
#   '172',
#   '75'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'G. Moya',
#   '20',
#   'CL',
#   '17',
#   'Centrocampista',
#   '174',
#   '65'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'P. SÃ¡nchez',
#   '24',
#   'CL',
#   '19',
#   'Centrocampista',
#   '173',
#   '63'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'R. Diaz',
#   '20',
#   'CL',
#   '27',
#   'Centrocampista',
#   '170',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'R. EcheverrÃ\xada',
#   '27',
#   'CL',
#   '20',
#   'Centrocampista',
#   '180',
#   '73'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'CristÃ³bal Chadwick',
#   '17',
#   'CL',
#   '33',
#   'Delantero',
#   '-',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'G. SepÃºlveda',
#   '20',
#   'CL',
#   '15',
#   'Delantero',
#   '155',
#   '47'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'J. Cuevas',
#   '34',
#   'AR',
#   '10',
#   'Delantero',
#   '161',
#   '63'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'L. Di Yorio',
#   '25',
#   'AR',
#   '7',
#   'Delantero',
#   '190',
#   '75'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'L. Pastran',
#   '20',
#   'AR',
#   '32',
#   'Delantero',
#   '173',
#   '72'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'M. Campos',
#   '31',
#   'CL',
#   '9',
#   'Delantero',
#   '177',
#   '81'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'M. Wassenne',
#   '21',
#   'CL',
#   '35',
#   'Delantero',
#   '-',
#   '-'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'P. Campos',
#   '22',
#   'CL',
#   '11',
#   'Delantero',
#   '173',
#   '64'],
#  ['Everton de ViÃ±a del Mar S.A.D.P.',
#   'V. I. Sosa',
#   '35',
#   'AR',
#   '18',
#   'Delantero',
#   '179',
#   '74'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'M. Ballesteros',
#   '20',
#   'CL',
#   '12',
#   'Portero',
#   '175',
#   '70'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'N. Peranic',
#   '37',
#   'AR',
#   '1',
#   'Portero',
#   '182',
#   '78'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'S. PÃ©rez',
#   '31',
#   'CL',
#   '25',
#   'Portero',
#   '180',
#   '76'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'T. Gillier',
#   '18',
#   'CL',
#   '28',
#   'Portero',
#   '184',
#   '68'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'A. Astudillo',
#   '22',
#   'VE',
#   '4',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'A. Parot',
#   '33',
#   'CL',
#   '24',
#   'Defensa',
#   '180',
#   '74'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'B. Ampuero',
#   '29',
#   'CL',
#   '17',
#   'Defensa',
#   '182',
#   '82'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'C. Arancibia',
#   '19',
#   'CL',
#   '41',
#   'Defensa',
#   '182',
#   '65'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'C. Cuevas',
#   '27',
#   'CL',
#   '15',
#   'Defensa',
#   '171',
#   '64'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'G. Lanaro',
#   '36',
#   'AR',
#   '2',
#   'Defensa',
#   '184',
#   '84'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'N. Paz',
#   '29',
#   'AR',
#   '6',
#   'Defensa',
#   '191',
#   '82'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'R. Rebolledo',
#   '25',
#   'CL',
#   '21',
#   'Defensa',
#   '171',
#   '63'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'T. Astaburuaga',
#   '26',
#   'CL',
#   '7',
#   'Defensa',
#   '185',
#   '71'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'B. GonzÃ¡lez',
#   '19',
#   'CL',
#   '31',
#   'Centrocampista',
#   '165',
#   '65'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'B. Iglesias',
#   '20',
#   'CL',
#   '36',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'D. Buonanotte',
#   '34',
#   'AR',
#   '18',
#   'Centrocampista',
#   '160',
#   '56'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'F. Gutierrez',
#   '32',
#   'CL',
#   '10',
#   'Centrocampista',
#   '170',
#   '64'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'I. Saavedra',
#   '23',
#   'CL',
#   '8',
#   'Centrocampista',
#   '172',
#   '65'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'J. Leiva',
#   '28',
#   'CL',
#   '22',
#   'Centrocampista',
#   '180',
#   '78'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'L. MuÃ±oz',
#   '18',
#   'CL',
#   '33',
#   'Centrocampista',
#   '186',
#   '79'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'M. NuÃ±ez',
#   '22',
#   'CL',
#   '26',
#   'Centrocampista',
#   '181',
#   '73'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'S. Galani',
#   '25',
#   'CL',
#   '13',
#   'Centrocampista',
#   '180',
#   '-'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'Bruno Barticciotto',
#   '21',
#   'CL',
#   '23',
#   'Delantero',
#   '177',
#   '70'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'C. Montes',
#   '21',
#   'CL',
#   '16',
#   'Delantero',
#   '178',
#   '68'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'C. Munder',
#   '22',
#   'CL',
#   '29',
#   'Delantero',
#   '165',
#   '62'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'D. Valencia',
#   '22',
#   'CL',
#   '30',
#   'Delantero',
#   '182',
#   '73'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'F. Orellana',
#   '36',
#   'CL',
#   '14',
#   'Delantero',
#   '169',
#   '68'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'F. Zampedri',
#   '34',
#   'AR',
#   '9',
#   'Delantero',
#   '179',
#   '72'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'G. Tapia',
#   '20',
#   'CL',
#   '20',
#   'Delantero',
#   '178',
#   '78'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'J. Fuenzalida',
#   '37',
#   'CL',
#   '19',
#   'Delantero',
#   '170',
#   '73'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'L. Melano',
#   '29',
#   'AR',
#   '27',
#   'Delantero',
#   '184',
#   '72'],
#  ['Club Deportivo Universidad CatÃ³lica',
#   'Y. Asad',
#   '28',
#   'AR',
#   '5',
#   'Delantero',
#   '178',
#   '74'],
#  ["Club Deportivo O'Higgins",
#   'A. Martin',
#   '30',
#   'AR',
#   '31',
#   'Portero',
#   '185',
#   '79'],
#  ["Club Deportivo O'Higgins",
#   'D. CarreÃ±o',
#   '20',
#   'CL',
#   '1',
#   'Portero',
#   '173',
#   '67'],
#  ["Club Deportivo O'Higgins",
#   'L. Ureta',
#   '23',
#   'CL',
#   '16',
#   'Portero',
#   '180',
#   '65'],
#  ["Club Deportivo O'Higgins",
#   'A. DÃ\xadaz',
#   '22',
#   'CL',
#   '30',
#   'Defensa',
#   '176',
#   '75'],
#  ["Club Deportivo O'Higgins",
#   'B. Torrealba',
#   '25',
#   'CL',
#   '23',
#   'Defensa',
#   '179',
#   '67'],
#  ["Club Deportivo O'Higgins",
#   'D. Carrasco',
#   '27',
#   'CL',
#   '18',
#   'Defensa',
#   '176',
#   '-'],
#  ["Club Deportivo O'Higgins",
#   'D. GonzÃ¡lez',
#   '24',
#   'CL',
#   '4',
#   'Defensa',
#   '184',
#   '78'],
#  ["Club Deportivo O'Higgins",
#   'F. Grillo',
#   '29',
#   'AR',
#   '37',
#   'Defensa',
#   '180',
#   '77'],
#  ["Club Deportivo O'Higgins",
#   'F. Hormazabal',
#   '26',
#   'CL',
#   '7',
#   'Defensa',
#   '172',
#   '67'],
#  ["Club Deportivo O'Higgins",
#   'J. Fuentes',
#   '27',
#   'CL',
#   '6',
#   'Defensa',
#   '175',
#   '70'],
#  ["Club Deportivo O'Higgins",
#   'M. GonzÃ¡lez',
#   '21',
#   'CL',
#   '27',
#   'Defensa',
#   '179',
#   '65'],
#  ["Club Deportivo O'Higgins",
#   'P. Romero',
#   '20',
#   'CL',
#   '24',
#   'Defensa',
#   '-',
#   '-'],
#  ["Club Deportivo O'Higgins",
#   'R. Guzman',
#   '20',
#   'CL',
#   '15',
#   'Defensa',
#   '-',
#   '-'],
#  ["Club Deportivo O'Higgins",
#   'A. Letelier',
#   '18',
#   'CL',
#   '',
#   'Centrocampista',
#   '165',
#   '51'],
#  ["Club Deportivo O'Higgins",
#   'C. Castillo',
#   '19',
#   'CL',
#   '2',
#   'Centrocampista',
#   '178',
#   '77'],
#  ["Club Deportivo O'Higgins",
#   'C. Moya',
#   '24',
#   'CL',
#   '13',
#   'Centrocampista',
#   '169',
#   '63'],
#  ["Club Deportivo O'Higgins",
#   'D. FernÃ¡ndez',
#   '24',
#   'CL',
#   '21',
#   'Centrocampista',
#   '175',
#   '70'],
#  ["Club Deportivo O'Higgins",
#   'D. GonzÃ¡lez',
#   '24',
#   'CL',
#   '',
#   'Centrocampista',
#   '173',
#   '70'],
#  ["Club Deportivo O'Higgins",
#   'Felipe Ogaz',
#   '19',
#   'CL',
#   '29',
#   'Centrocampista',
#   '-',
#   '-'],
#  ["Club Deportivo O'Higgins",
#   'G. Lodico',
#   '24',
#   'AR',
#   '32',
#   'Centrocampista',
#   '162',
#   '63'],
#  ["Club Deportivo O'Higgins",
#   'M. MarÃ\xadn',
#   '22',
#   'CL',
#   '20',
#   'Centrocampista',
#   '169',
#   '64'],
#  ["Club Deportivo O'Higgins",
#   'P. HernÃ¡ndez',
#   '35',
#   'CL',
#   '8',
#   'Centrocampista',
#   '183',
#   '76'],
#  ["Club Deportivo O'Higgins",
#   'E. Moreira',
#   '20',
#   'CL',
#   '33',
#   'Delantero',
#   '-',
#   '-'],
#  ["Club Deportivo O'Higgins",
#   'F. Arancibia',
#   '25',
#   'CL',
#   '28',
#   'Delantero',
#   '170',
#   '69'],
#  ["Club Deportivo O'Higgins",
#   'F. Barcelo',
#   '29',
#   'UY',
#   '22',
#   'Delantero',
#   '174',
#   '68'],
#  ["Club Deportivo O'Higgins",
#   'F. Castro',
#   '27',
#   'UY',
#   '11',
#   'Delantero',
#   '172',
#   '65'],
#  ["Club Deportivo O'Higgins",
#   'M. Belmar',
#   '20',
#   'CL',
#   '19',
#   'Delantero',
#   '177',
#   '76'],
#  ["Club Deportivo O'Higgins",
#   'M. Donoso',
#   '36',
#   'CL',
#   '9',
#   'Delantero',
#   '186',
#   '78'],
#  ["Club Deportivo O'Higgins",
#   'S. Ubilla',
#   '32',
#   'CL',
#   '10',
#   'Delantero',
#   '172',
#   '72'],
#  ['Union EspaÃ±ola S.A.D.P.', 'F. Soto', '16', 'CL', '', 'Portero', '-', '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'J. Echave',
#   '21',
#   'CL',
#   '12',
#   'Portero',
#   '180',
#   '68'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'L. Mejia',
#   '31',
#   'PA',
#   '31',
#   'Portero',
#   '190',
#   '80'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'M. Pinto',
#   '39',
#   'CL',
#   '1',
#   'Portero',
#   '175',
#   '70'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'A. Barrios',
#   '31',
#   'CL',
#   '16',
#   'Defensa',
#   '183',
#   '78'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'J. Villagra',
#   '21',
#   'CL',
#   '28',
#   'Defensa',
#   '180',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'K. Contreras',
#   '17',
#   'CL',
#   '38',
#   'Defensa',
#   '-',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'L. Pavez',
#   '34',
#   'CL',
#   '6',
#   'Defensa',
#   '175',
#   '70'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'M. FernÃ¡ndez',
#   '33',
#   'UY',
#   '33',
#   'Defensa',
#   '181',
#   '79'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'M. Larenas',
#   '29',
#   'CL',
#   '19',
#   'Defensa',
#   '174',
#   '68'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'S. Magnasco',
#   '30',
#   'CL',
#   '29',
#   'Defensa',
#   '175',
#   '72'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'T. Galdames',
#   '23',
#   'CL',
#   '3',
#   'Defensa',
#   '182',
#   '72'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'V. Conelli',
#   '19',
#   'CL',
#   '20',
#   'Defensa',
#   '180',
#   '73'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'B. Rabello',
#   '28',
#   'CL',
#   '14',
#   'Centrocampista',
#   '168',
#   '65'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'C. Espinoza',
#   '20',
#   'CL',
#   '32',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'D. Acevedo',
#   '21',
#   'CL',
#   '25',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'F. Massri',
#   '-',
#   'CH',
#   '36',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'G. Espinoza',
#   '32',
#   'CL',
#   '21',
#   'Centrocampista',
#   '178',
#   '79'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'I. IbÃ¡Ã±ez',
#   '26',
#   'CL',
#   '11',
#   'Centrocampista',
#   '178',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'I. Jara',
#   '25',
#   'CL',
#   '18',
#   'Centrocampista',
#   '168',
#   '60'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'J. Silva',
#   '21',
#   'CL',
#   '',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'L. Pavez',
#   '27',
#   'CL',
#   '6',
#   'Centrocampista',
#   '175',
#   '69'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'S. Leyton',
#   '29',
#   'CL',
#   '5',
#   'Centrocampista',
#   '177',
#   '74'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'V. Vidal',
#   '-',
#   'CL',
#   '37',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'B. Galdames',
#   '21',
#   'MX',
#   '27',
#   'Delantero',
#   '171',
#   '61'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'B. YaÃ±ez',
#   '21',
#   'CL',
#   '22',
#   'Delantero',
#   '173',
#   '72'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'G. Norambuena',
#   '19',
#   'CL',
#   '24',
#   'Delantero',
#   '176',
#   '-'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'J. Sierra',
#   '25',
#   'CL',
#   '',
#   'Delantero',
#   '183',
#   '83'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'L. Garate',
#   '29',
#   'AR',
#   '9',
#   'Delantero',
#   '190',
#   '87'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'R. PiÃ±eiro',
#   '23',
#   'UY',
#   '7',
#   'Delantero',
#   '175',
#   '66'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'R. Rivero',
#   '30',
#   'UY',
#   '10',
#   'Delantero',
#   '187',
#   '80'],
#  ['Union EspaÃ±ola S.A.D.P.',
#   'S. Jaime',
#   '35',
#   'AR',
#   '23',
#   'Delantero',
#   '179',
#   '69'],
#  ['Club Deportivo Palestino',
#   'D. Contreras',
#   '20',
#   'CL',
#   '26',
#   'Portero',
#   '-',
#   '-'],
#  ['Club Deportivo Palestino',
#   'D. Sappa',
#   '27',
#   'AR',
#   '17',
#   'Portero',
#   '193',
#   '90'],
#  ['Club Deportivo Palestino',
#   'G. Fuentes',
#   '19',
#   'CL',
#   '',
#   'Portero',
#   '188',
#   '88'],
#  ['Club Deportivo Palestino',
#   'N. Veloso',
#   '35',
#   'CL',
#   '1',
#   'Portero',
#   '181',
#   '79'],
#  ['Club Deportivo Palestino',
#   'A. Riquelme',
#   '-',
#   'CL',
#   '39',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club Deportivo Palestino',
#   'B. Rojas',
#   '21',
#   'CL',
#   '3',
#   'Defensa',
#   '179',
#   '80'],
#  ['Club Deportivo Palestino',
#   'B. VÃ©jar',
#   '27',
#   'CL',
#   '19',
#   'Defensa',
#   '168',
#   '63'],
#  ['Club Deportivo Palestino',
#   'C. Suarez',
#   '35',
#   'CL',
#   '13',
#   'Defensa',
#   '180',
#   '73'],
#  ['Club Deportivo Palestino',
#   'F. Pardo',
#   '25',
#   'AR',
#   '2',
#   'Defensa',
#   '183',
#   '80'],
#  ['Club Deportivo Palestino',
#   'I. Mesina',
#   '21',
#   'CL',
#   '4',
#   'Defensa',
#   '183',
#   '77'],
#  ['Club Deportivo Palestino',
#   'J. Bizama',
#   '28',
#   'CL',
#   '16',
#   'Defensa',
#   '178',
#   '75'],
#  ['Club Deportivo Palestino',
#   'Maicol LeÃ³n',
#   '19',
#   'CL',
#   '24',
#   'Defensa',
#   '174',
#   '62'],
#  ['Club Deportivo Palestino',
#   'S. Cabrera',
#   '24',
#   'CL',
#   '27',
#   'Defensa',
#   '176',
#   '69'],
#  ['Club Deportivo Palestino',
#   'V. Fernandez',
#   '23',
#   'CL',
#   '15',
#   'Defensa',
#   '180',
#   '67'],
#  ['Club Deportivo Palestino',
#   'A. FarÃ\xadas',
#   '34',
#   'AR',
#   '5',
#   'Centrocampista',
#   '181',
#   '74'],
#  ['Club Deportivo Palestino',
#   'A. MartÃ\xadnez',
#   '28',
#   'CL',
#   '23',
#   'Centrocampista',
#   '176',
#   '79'],
#  ['Club Deportivo Palestino',
#   'F. Chamorro',
#   '21',
#   'CL',
#   '22',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Deportivo Palestino',
#   'M. DÃ¡vila',
#   '31',
#   'CL',
#   '8',
#   'Centrocampista',
#   '172',
#   '67'],
#  ['Club Deportivo Palestino',
#   'M. DÃ\xadaz',
#   '31',
#   'AR',
#   '20',
#   'Centrocampista',
#   '170',
#   '62'],
#  ['Club Deportivo Palestino',
#   'N. Meza',
#   '20',
#   'CL',
#   '6',
#   'Centrocampista',
#   '172',
#   '68'],
#  ['Club Deportivo Palestino',
#   'A. Vilches',
#   '30',
#   'CL',
#   '9',
#   'Delantero',
#   '182',
#   '80'],
#  ['Club Deportivo Palestino',
#   'B. Carrasco',
#   '31',
#   'CL',
#   '7',
#   'Delantero',
#   '169',
#   '64'],
#  ['Club Deportivo Palestino',
#   'B. Soto',
#   '20',
#   'CL',
#   '28',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club Deportivo Palestino',
#   'Bruno Barticciotto',
#   '21',
#   'CL',
#   '14',
#   'Delantero',
#   '177',
#   '70'],
#  ['Club Deportivo Palestino',
#   'D. Salgado',
#   '19',
#   'CL',
#   '25',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club Deportivo Palestino',
#   'J. BenÃ\xadtez',
#   '31',
#   'AR',
#   '11',
#   'Delantero',
#   '176',
#   '73'],
#  ['Club Deportivo Palestino',
#   'M. Salas',
#   '24',
#   'AR',
#   '18',
#   'Delantero',
#   '173',
#   '87'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'I. Arce',
#   '30',
#   'AR',
#   '1',
#   'Portero',
#   '185',
#   '74'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'J. Tapia',
#   '-',
#   'CL',
#   '25',
#   'Portero',
#   '-',
#   '-'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'R. Cancino',
#   '22',
#   'CL',
#   '12',
#   'Portero',
#   '180',
#   '79'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'C. Vilches',
#   '39',
#   'CL',
#   '17',
#   'Defensa',
#   '181',
#   '79'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'E. Wiemberg',
#   '28',
#   'CL',
#   '11',
#   'Defensa',
#   '178',
#   '-'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'F. Robles',
#   '21',
#   'CL',
#   '3',
#   'Defensa',
#   '187',
#   '-'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'H. Sanhueza',
#   '26',
#   'CL',
#   '15',
#   'Defensa',
#   '179',
#   '66'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'M. Fernandez',
#   '27',
#   'CL',
#   '13',
#   'Defensa',
#   '170',
#   '60'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'P. Flores',
#   '20',
#   'CL',
#   '6',
#   'Defensa',
#   '175',
#   '65'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'P. Henrique',
#   '21',
#   'BR',
#   '23',
#   'Defensa',
#   '187',
#   '80'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'S. GarcÃ\xada',
#   '34',
#   'AR',
#   '2',
#   'Defensa',
#   '192',
#   '90'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'S. RamÃ\xadrez',
#   '23',
#   'CL',
#   '14',
#   'Defensa',
#   '178',
#   '70'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'Y. Oyanedel',
#   '22',
#   'CL',
#   '4',
#   'Defensa',
#   '168',
#   '72'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'A. Moreno',
#   '20',
#   'CL',
#   '27',
#   'Centrocampista',
#   '170',
#   '-'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'B. Garrido',
#   '23',
#   'CL',
#   '20',
#   'Centrocampista',
#   '173',
#   '66'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'C. PÃ©rez',
#   '19',
#   'CL',
#   '46',
#   'Centrocampista',
#   '176',
#   '66'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'E. Valencia',
#   '23',
#   'CL',
#   '5',
#   'Centrocampista',
#   '172',
#   '70'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'F. Gonzalez',
#   '20',
#   'CL',
#   '',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'G. Castellani',
#   '35',
#   'AR',
#   '10',
#   'Centrocampista',
#   '183',
#   '78'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'M. Vidangossy',
#   '35',
#   'CL',
#   '16',
#   'Centrocampista',
#   '172',
#   '67'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'W. AlarcÃ³n',
#   '21',
#   'CL',
#   '8',
#   'Centrocampista',
#   '176',
#   '69'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'B. Carvallo',
#   '26',
#   'CL',
#   '21',
#   'Delantero',
#   '164',
#   '61'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'D. Moreno',
#   '20',
#   'CL',
#   '19',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'L. Passerini',
#   '28',
#   'AR',
#   '9',
#   'Delantero',
#   '189',
#   '84'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'M. Cavalleri',
#   '24',
#   'CL',
#   '7',
#   'Delantero',
#   '168',
#   '60'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'N. Orellana',
#   '27',
#   'CL',
#   '22',
#   'Delantero',
#   '180',
#   '67'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'S. Saez',
#   '37',
#   'AR',
#   '18',
#   'Delantero',
#   '178',
#   '80'],
#  ['Club Deportivo UniÃ³n La Calera',
#   'T. Rodriguez',
#   '26',
#   'CL',
#   '32',
#   'Delantero',
#   '183',
#   '73'],
#  ['Club Deportivo Huachipato',
#   'G. CastellÃ³n',
#   '29',
#   'CL',
#   '25',
#   'Portero',
#   '190',
#   '82'],
#  ['Club Deportivo Huachipato',
#   'JosÃ© MartÃ\xadnez',
#   '19',
#   'CL',
#   '31',
#   'Portero',
#   '185',
#   '78'],
#  ['Club Deportivo Huachipato',
#   'Y. Urra',
#   '26',
#   'CL',
#   '1',
#   'Portero',
#   '189',
#   '86'],
#  ['Club Deportivo Huachipato',
#   'A. Castillo',
#   '23',
#   'CL',
#   '2',
#   'Defensa',
#   '175',
#   '74'],
#  ['Club Deportivo Huachipato',
#   'B. Gazzolo',
#   '25',
#   'CL',
#   '4',
#   'Defensa',
#   '181',
#   '77'],
#  ['Club Deportivo Huachipato',
#   'B. Roco',
#   '18',
#   'CL',
#   '26',
#   'Defensa',
#   '183',
#   '78'],
#  ['Club Deportivo Huachipato',
#   'D. Aravena',
#   '21',
#   'CL',
#   '13',
#   'Defensa',
#   '170',
#   '70'],
#  ['Club Deportivo Huachipato',
#   'J. CÃ³rdova',
#   '27',
#   'CA',
#   '11',
#   'Defensa',
#   '165',
#   '63'],
#  ['Club Deportivo Huachipato',
#   'J. GutiÃ©rrez',
#   '20',
#   'CL',
#   '18',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club Deportivo Huachipato',
#   'J. Molina',
#   '22',
#   'CL',
#   '21',
#   'Defensa',
#   '171',
#   '64'],
#  ['Club Deportivo Huachipato',
#   'Juaquin Gutierrez',
#   '20',
#   'CL',
#   '18',
#   'Defensa',
#   '172',
#   '70'],
#  ['Club Deportivo Huachipato',
#   'N. RamÃ\xadrez',
#   '25',
#   'CL',
#   '5',
#   'Defensa',
#   '182',
#   '82'],
#  ['Club Deportivo Huachipato',
#   'O. GonzÃ¡lez',
#   '38',
#   'CL',
#   '3',
#   'Defensa',
#   '182',
#   '80'],
#  ['Club Deportivo Huachipato',
#   'R. Malanca',
#   '19',
#   'AR',
#   '22',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club Deportivo Huachipato',
#   'A. Garrido',
#   '22',
#   'CL',
#   '27',
#   'Centrocampista',
#   '173',
#   '71'],
#  ['Club Deportivo Huachipato',
#   'B. Palmezano',
#   '22',
#   'VE',
#   '',
#   'Centrocampista',
#   '169',
#   '69'],
#  ['Club Deportivo Huachipato',
#   'C. Lobos',
#   '25',
#   'CL',
#   '16',
#   'Centrocampista',
#   '173',
#   '70'],
#  ['Club Deportivo Huachipato',
#   'C. SepÃºlveda',
#   '30',
#   'CL',
#   '6',
#   'Centrocampista',
#   '175',
#   '76'],
#  ['Club Deportivo Huachipato',
#   'C. Torres',
#   '19',
#   'CL',
#   '29',
#   'Centrocampista',
#   '178',
#   '77'],
#  ['Club Deportivo Huachipato',
#   'D. Bravo',
#   '20',
#   'CL',
#   '30',
#   'Centrocampista',
#   '174',
#   '72'],
#  ['Club Deportivo Huachipato',
#   'G. Montes',
#   '27',
#   'UY',
#   '8',
#   'Centrocampista',
#   '174',
#   '74'],
#  ['Club Deportivo Huachipato',
#   'J. Altamirano',
#   '23',
#   'CL',
#   '14',
#   'Centrocampista',
#   '172',
#   '68'],
#  ['Club Deportivo Huachipato',
#   'Jimmy MartÃ\xadnez',
#   '25',
#   'CL',
#   '20',
#   'Centrocampista',
#   '178',
#   '67'],
#  ['Club Deportivo Huachipato',
#   'M. CaÃ±ete',
#   '32',
#   'AR',
#   '19',
#   'Centrocampista',
#   '182',
#   '76'],
#  ['Club Deportivo Huachipato',
#   'N. Baeza',
#   '25',
#   'CL',
#   '17',
#   'Centrocampista',
#   '175',
#   '75'],
#  ['Club Deportivo Huachipato',
#   'P. ChandÃ\xada',
#   '20',
#   'CL',
#   '33',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Deportivo Huachipato',
#   'C. Martinez',
#   '29',
#   'PY',
#   '23',
#   'Delantero',
#   '172',
#   '70'],
#  ['Club Deportivo Huachipato',
#   'J. SÃ¡nchez Sotelo',
#   '35',
#   'AR',
#   '9',
#   'Delantero',
#   '180',
#   '77'],
#  ['Club Deportivo Huachipato',
#   'L. Nequecaur',
#   '30',
#   'AR',
#   '32',
#   'Delantero',
#   '192',
#   '87'],
#  ['Club Deportivo Huachipato',
#   'M. RodrÃ\xadguez',
#   '22',
#   'CL',
#   '15',
#   'Delantero',
#   '172',
#   '68'],
#  ['Club Deportivo Huachipato',
#   'N. Silva',
#   '23',
#   'CL',
#   '19',
#   'Delantero',
#   '167',
#   '66'],
#  ['Club Deportivo Huachipato',
#   'W. Mazzantti',
#   '26',
#   'AR',
#   '7',
#   'Delantero',
#   '175',
#   '68'],
#  ['Club Universidad de Chile',
#   'C. Campos',
#   '23',
#   'CL',
#   '25',
#   'Portero',
#   '185',
#   '82'],
#  ['Club Universidad de Chile',
#   'I. SÃ¡ez',
#   '-',
#   'CL',
#   '29',
#   'Portero',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'M. Parra',
#   '22',
#   'CL',
#   '12',
#   'Portero',
#   '186',
#   '78'],
#  ['Club Universidad de Chile',
#   'P. Garrido',
#   '18',
#   'CL',
#   '1',
#   'Portero',
#   '187',
#   '76'],
#  ['Club Universidad de Chile',
#   'BastiÃ¡n Tapia',
#   '20',
#   'CL',
#   '21',
#   'Defensa',
#   '182',
#   '77'],
#  ['Club Universidad de Chile',
#   'I. Tapia',
#   '23',
#   'CL',
#   '21',
#   'Defensa',
#   '186',
#   '72'],
#  ['Club Universidad de Chile',
#   'J. Castro',
#   '21',
#   'CL',
#   '4',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'L. Casanova',
#   '30',
#   'CL',
#   '17',
#   'Defensa',
#   '182',
#   '80'],
#  ['Club Universidad de Chile',
#   'Marcelo Morales',
#   '19',
#   'CL',
#   '23',
#   'Defensa',
#   '177',
#   '56'],
#  ['Club Universidad de Chile',
#   'N. DomÃ\xadnguez',
#   '32',
#   'AR',
#   '32',
#   'Defensa',
#   '184',
#   '79'],
#  ['Club Universidad de Chile',
#   'Y. AndÃ\xada',
#   '30',
#   'CL',
#   '6',
#   'Defensa',
#   '175',
#   '71'],
#  ['Club Universidad de Chile',
#   'A. Arce',
#   '17',
#   'CL',
#   '30',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'Ã\x81. Brun',
#   '35',
#   'UY',
#   '26',
#   'Centrocampista',
#   '186',
#   '87'],
#  ['Club Universidad de Chile',
#   'D. Navarrete',
#   '21',
#   'CL',
#   '2',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'D. Osorio',
#   '18',
#   'CL',
#   '24',
#   'Centrocampista',
#   '182',
#   '67'],
#  ['Club Universidad de Chile',
#   'E. FernÃ¡ndez',
#   '20',
#   'CL',
#   '27',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'F. Seymour',
#   '35',
#   'CL',
#   '14',
#   'Centrocampista',
#   '174',
#   '71'],
#  ['Club Universidad de Chile',
#   'I. Poblete',
#   '27',
#   'CL',
#   '28',
#   'Centrocampista',
#   '171',
#   '70'],
#  ['Club Universidad de Chile',
#   'L. Gallegos',
#   '30',
#   'CL',
#   '15',
#   'Centrocampista',
#   '173',
#   '73'],
#  ['Club Universidad de Chile',
#   'Lucas Assadi',
#   '18',
#   'CL',
#   '20',
#   'Centrocampista',
#   '172',
#   '67'],
#  ['Club Universidad de Chile',
#   'Mauricio Morales',
#   '22',
#   'CL',
#   '7',
#   'Centrocampista',
#   '169',
#   '67'],
#  ['Club Universidad de Chile',
#   'P. ArÃ¡nguiz',
#   '25',
#   'CL',
#   '8',
#   'Centrocampista',
#   '172',
#   '71'],
#  ['Club Universidad de Chile',
#   'P. Ojeda',
#   '24',
#   'AR',
#   '5',
#   'Centrocampista',
#   '180',
#   '72'],
#  ['Club Universidad de Chile',
#   'R. Cordero',
#   '19',
#   'CL',
#   '33',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'C. MuÃ±oz',
#   '20',
#   'CL',
#   '22',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club Universidad de Chile',
#   'C. Palacios',
#   '32',
#   'UY',
#   '11',
#   'Delantero',
#   '171',
#   '70'],
#  ['Club Universidad de Chile',
#   'F. Lobos',
#   '23',
#   'CL',
#   '18',
#   'Delantero',
#   '180',
#   '72'],
#  ['Club Universidad de Chile',
#   'J. FernÃ¡ndes',
#   '34',
#   'CL',
#   '9',
#   'Delantero',
#   '184',
#   '74'],
#  ['Club Universidad de Chile',
#   'J. Vargas',
#   '25',
#   'CL',
#   '10',
#   'Delantero',
#   '160',
#   '60'],
#  ['Club Universidad de Chile',
#   'R. FernÃ¡ndez',
#   '31',
#   'CL',
#   '19',
#   'Delantero',
#   '185',
#   '81'],
#  ['Club de Deportes La Serena',
#   'G. Fuentealba',
#   '27',
#   'CL',
#   '1',
#   'Portero',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'J. DÃ\xadaz',
#   '19',
#   'CL',
#   '36',
#   'Portero',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'J. Tapia',
#   '20',
#   'CL',
#   '12',
#   'Portero',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'Z. LÃ³pez',
#   '24',
#   'CL',
#   '17',
#   'Portero',
#   '183',
#   '78'],
#  ['Club de Deportes La Serena',
#   'Enzo Ferrario',
#   '22',
#   'CL',
#   '3',
#   'Defensa',
#   '182',
#   '72'],
#  ['Club de Deportes La Serena',
#   'J. Buss',
#   '25',
#   'CL',
#   '2',
#   'Defensa',
#   '185',
#   '-'],
#  ['Club de Deportes La Serena',
#   'L. AlarcÃ³n',
#   '22',
#   'CL',
#   '5',
#   'Defensa',
#   '183',
#   '82'],
#  ['Club de Deportes La Serena',
#   'L. DÃ\xadaz',
#   '23',
#   'CL',
#   '4',
#   'Defensa',
#   '173',
#   '67'],
#  ['Club de Deportes La Serena',
#   'M. Cortes',
#   '19',
#   'CL',
#   '32',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'M. Herrera',
#   '30',
#   'AR',
#   '20',
#   'Defensa',
#   '182',
#   '82'],
#  ['Club de Deportes La Serena',
#   'M. RamÃ\xadrez',
#   '18',
#   'CL',
#   '29',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'R. Brito',
#   '39',
#   'CL',
#   '6',
#   'Defensa',
#   '174',
#   '72'],
#  ['Club de Deportes La Serena',
#   'V. Ramon',
#   '22',
#   'BR',
#   '15',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'A. QuiÃ±ones',
#   '24',
#   'CL',
#   '25',
#   'Centrocampista',
#   '173',
#   '70'],
#  ['Club de Deportes La Serena',
#   'Bryan Soto',
#   '21',
#   'CL',
#   '24',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'C. Erbes',
#   '32',
#   'AR',
#   '21',
#   'Centrocampista',
#   '172',
#   '74'],
#  ['Club de Deportes La Serena',
#   'C. Jorquera',
#   '34',
#   'CL',
#   '8',
#   'Centrocampista',
#   '174',
#   '69'],
#  ['Club de Deportes La Serena',
#   'C. VÃ¡squez',
#   '25',
#   'CL',
#   '37',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'Diego Ulloa',
#   '19',
#   'CL',
#   '23',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'G. Zuleta',
#   '21',
#   'CL',
#   '28',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'J. CarreÃ±o',
#   '25',
#   'CL',
#   '31',
#   'Centrocampista',
#   '166',
#   '66'],
#  ['Club de Deportes La Serena',
#   'J. Cavallaro',
#   '28',
#   'AR',
#   '30',
#   'Centrocampista',
#   '171',
#   '68'],
#  ['Club de Deportes La Serena',
#   'J. Fuentealba',
#   '19',
#   'CL',
#   '27',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'L. CarreÃ±o',
#   '19',
#   'CL',
#   '13',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'Leo Valencia',
#   '31',
#   'CL',
#   '10',
#   'Centrocampista',
#   '181',
#   '79'],
#  ['Club de Deportes La Serena',
#   'M. FernÃ¡ndez',
#   '36',
#   'CL',
#   '14',
#   'Centrocampista',
#   '178',
#   '72'],
#  ['Club de Deportes La Serena',
#   'M. Guerrero',
#   '22',
#   'CL',
#   '7',
#   'Centrocampista',
#   '170',
#   '-'],
#  ['Club de Deportes La Serena',
#   'S. Dittborn',
#   '29',
#   'CL',
#   '19',
#   'Centrocampista',
#   '174',
#   '70'],
#  ['Club de Deportes La Serena',
#   'A. CÃ¡ceres',
#   '22',
#   'CL',
#   '16',
#   'Delantero',
#   '181',
#   '72'],
#  ['Club de Deportes La Serena',
#   'D. Campusano',
#   '20',
#   'CL',
#   '38',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'F. Andrada',
#   '28',
#   'AR',
#   '9',
#   'Delantero',
#   '181',
#   '74'],
#  ['Club de Deportes La Serena',
#   'F. Diaz',
#   '20',
#   'CL',
#   '33',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes La Serena',
#   'H. Suazo',
#   '41',
#   'CL',
#   '26',
#   'Delantero',
#   '172',
#   '76'],
#  ['Club de Deportes La Serena',
#   'R. Paredes',
#   '24',
#   'CL',
#   '11',
#   'Delantero',
#   '178',
#   '69'],
#  ['Club de Deportes Antofagasta',
#   'D. SÃ¡nchez',
#   '35',
#   'CL',
#   '13',
#   'Portero',
#   '182',
#   '85'],
#  ['Club de Deportes Antofagasta',
#   'I. Gonzalez',
#   '32',
#   'CL',
#   '1',
#   'Portero',
#   '187',
#   '81'],
#  ['Club de Deportes Antofagasta',
#   'J. Cisternas',
#   '20',
#   'CL',
#   '30',
#   'Portero',
#   '-',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'A. Robles',
#   '28',
#   'CL',
#   '29',
#   'Defensa',
#   '180',
#   '74'],
#  ['Club de Deportes Antofagasta',
#   'B. Nieto',
#   '24',
#   'CL',
#   '23',
#   'Defensa',
#   '-',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'C. DÃ\xadaz',
#   '19',
#   'CL',
#   '18',
#   'Defensa',
#   '182',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'C. RodrÃ\xadguez',
#   '27',
#   'CL',
#   '26',
#   'Defensa',
#   '166',
#   '62'],
#  ['Club de Deportes Antofagasta',
#   'C. Rojas',
#   '36',
#   'CL',
#   '5',
#   'Defensa',
#   '171',
#   '68'],
#  ['Club de Deportes Antofagasta',
#   'E. Ahumada',
#   '28',
#   'CL',
#   '32',
#   'Defensa',
#   '183',
#   '73'],
#  ['Club de Deportes Antofagasta',
#   'J. Cornejo',
#   '32',
#   'CL',
#   '15',
#   'Defensa',
#   '176',
#   '75'],
#  ['Club de Deportes Antofagasta',
#   'L. Vega',
#   '26',
#   'AR',
#   '3',
#   'Defensa',
#   '179',
#   '77'],
#  ['Club de Deportes Antofagasta',
#   'P. MagalhÃ£es',
#   '32',
#   'CL',
#   '17',
#   'Defensa',
#   '175',
#   '74'],
#  ['Club de Deportes Antofagasta',
#   'S. Cordero',
#   '26',
#   'CL',
#   '14',
#   'Defensa',
#   '177',
#   '60'],
#  ['Club de Deportes Antofagasta',
#   'S. GonzÃ¡lez',
#   '22',
#   'CL',
#   '4',
#   'Defensa',
#   '195',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'A. Cuadra',
#   '24',
#   'CL',
#   '20',
#   'Centrocampista',
#   '173',
#   '68'],
#  ['Club de Deportes Antofagasta',
#   'A. Souper',
#   '23',
#   'CL',
#   '21',
#   'Centrocampista',
#   '173',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'Diego Ignacio Orellana',
#   '20',
#   'CL',
#   '22',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'F. Bravo',
#   '29',
#   'AR',
#   '6',
#   'Centrocampista',
#   '185',
#   '82'],
#  ['Club de Deportes Antofagasta',
#   'I. Ledezma',
#   '27',
#   'CL',
#   '7',
#   'Centrocampista',
#   '176',
#   '69'],
#  ['Club de Deportes Antofagasta',
#   'M. Collao',
#   '24',
#   'CL',
#   '8',
#   'Centrocampista',
#   '173',
#   '67'],
#  ['Club de Deportes Antofagasta',
#   'Maykol Sanchez',
#   '20',
#   'CL',
#   '16',
#   'Centrocampista',
#   '174',
#   '63'],
#  ['Club de Deportes Antofagasta',
#   'A. Uribe',
#   '23',
#   'CL',
#   '11',
#   'Delantero',
#   '166',
#   '69'],
#  ['Club de Deportes Antofagasta',
#   'B. Hurtado',
#   '23',
#   'VE',
#   '24',
#   'Delantero',
#   '184',
#   '70'],
#  ['Club de Deportes Antofagasta',
#   'Diego Felipe Orellana',
#   '29',
#   'CL',
#   '22',
#   'Delantero',
#   '173',
#   '59'],
#  ['Club de Deportes Antofagasta',
#   'G. Tello',
#   '29',
#   'CL',
#   '19',
#   'Delantero',
#   '166',
#   '65'],
#  ['Club de Deportes Antofagasta',
#   'G. Torres',
#   '33',
#   'PA',
#   '28',
#   'Delantero',
#   '175',
#   '75'],
#  ['Club de Deportes Antofagasta',
#   'J. Flores',
#   '25',
#   'CL',
#   '10',
#   'Delantero',
#   '167',
#   '57'],
#  ['Club de Deportes Antofagasta',
#   'M. Fredes',
#   '19',
#   'CL',
#   '31',
#   'Delantero',
#   '-',
#   '-'],
#  ['Club de Deportes Antofagasta',
#   'M. LÃ³pez',
#   '26',
#   'AR',
#   '9',
#   'Delantero',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'G. Orellana',
#   '36',
#   'CL',
#   '12',
#   'Portero',
#   '182',
#   '82'],
#  ['Coquimbo Unido S.A.D.P.',
#   'M. Vergara',
#   '21',
#   'CL',
#   '34',
#   'Portero',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'R. Formento',
#   '23',
#   'UY',
#   '25',
#   'Portero',
#   '181',
#   '76'],
#  ['Coquimbo Unido S.A.D.P.',
#   'C. Barrera',
#   '24',
#   'CL',
#   '2',
#   'Defensa',
#   '180',
#   '66'],
#  ['Coquimbo Unido S.A.D.P.',
#   'D. ZÃºÃ±iga',
#   '26',
#   'CL',
#   '28',
#   'Defensa',
#   '170',
#   '77'],
#  ['Coquimbo Unido S.A.D.P.',
#   'F. Pereyra',
#   '33',
#   'AR',
#   '29',
#   'Defensa',
#   '179',
#   '81'],
#  ['Coquimbo Unido S.A.D.P.',
#   'G. Gordillo',
#   '28',
#   'GT',
#   '27',
#   'Defensa',
#   '187',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'G. Jara',
#   '37',
#   'CL',
#   '18',
#   'Defensa',
#   '178',
#   '77'],
#  ['Coquimbo Unido S.A.D.P.',
#   'N. Berardo',
#   '32',
#   'AR',
#   '16',
#   'Defensa',
#   '177',
#   '63'],
#  ['Coquimbo Unido S.A.D.P.',
#   'R. Escobar',
#   '24',
#   'CL',
#   '3',
#   'Defensa',
#   '180',
#   '72'],
#  ['Coquimbo Unido S.A.D.P.',
#   'C. Aravena',
#   '24',
#   'CL',
#   '31',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'C. MarÃ\xadn',
#   '28',
#   'CL',
#   '22',
#   'Centrocampista',
#   '166',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'D. Escobar',
#   '21',
#   'CL',
#   '5',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'F. Carmona',
#   '28',
#   'CL',
#   '26',
#   'Centrocampista',
#   '176',
#   '70'],
#  ['Coquimbo Unido S.A.D.P.',
#   'F. CortÃ©s',
#   '22',
#   'CL',
#   '24',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'F. Villagran',
#   '25',
#   'CL',
#   '20',
#   'Centrocampista',
#   '185',
#   '76'],
#  ['Coquimbo Unido S.A.D.P.',
#   'J. Abrigo',
#   '27',
#   'CL',
#   '10',
#   'Centrocampista',
#   '169',
#   '58'],
#  ['Coquimbo Unido S.A.D.P.',
#   'J. Bravo',
#   '21',
#   'CL',
#   '15',
#   'Centrocampista',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'J. GatÃ\xadca',
#   '26',
#   'CL',
#   '6',
#   'Centrocampista',
#   '171',
#   '64'],
#  ['Coquimbo Unido S.A.D.P.',
#   'L. Cabrera',
#   '28',
#   'CL',
#   '8',
#   'Centrocampista',
#   '168',
#   '61'],
#  ['Coquimbo Unido S.A.D.P.',
#   'S. Galani',
#   '25',
#   'CL',
#   '7',
#   'Centrocampista',
#   '180',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'V. GonzÃ¡lez',
#   '28',
#   'CL',
#   '23',
#   'Centrocampista',
#   '178',
#   '80'],
#  ['Coquimbo Unido S.A.D.P.',
#   'Ã\x81. Ramos',
#   '30',
#   'CL',
#   '11',
#   'Delantero',
#   '167',
#   '77'],
#  ['Coquimbo Unido S.A.D.P.',
#   'C. Huanca',
#   '21',
#   'CL',
#   '9',
#   'Delantero',
#   '180',
#   '79'],
#  ['Coquimbo Unido S.A.D.P.',
#   'F. Barrientos',
#   '25',
#   'CL',
#   '13',
#   'Delantero',
#   '169',
#   '65'],
#  ['Coquimbo Unido S.A.D.P.',
#   'F. YÃ¡Ã±ez',
#   '17',
#   'CL',
#   '4',
#   'Delantero',
#   '176',
#   '73'],
#  ['Coquimbo Unido S.A.D.P.',
#   'I. Jeraldino',
#   '26',
#   'CL',
#   '19',
#   'Delantero',
#   '184',
#   '74'],
#  ['Coquimbo Unido S.A.D.P.',
#   'M. Alvarado',
#   '19',
#   'CL',
#   '34',
#   'Delantero',
#   '-',
#   '-'],
#  ['Coquimbo Unido S.A.D.P.',
#   'N. Gauna',
#   '30',
#   'AR',
#   '30',
#   'Delantero',
#   '177',
#   '69'],
#  ['Coquimbo Unido S.A.D.P.',
#   'R. FarfÃ¡n',
#   '31',
#   'CL',
#   '17',
#   'Delantero',
#   '178',
#   '69'],
#  ['Coquimbo Unido S.A.D.P.', 'G. Araya', '-', 'CL', '39', '', '-', '-']]

# %%
import pandas as pd

# %%
#Expreso como DataFrame
plantillas_df = pd.DataFrame(plantilla_final)
plantillas_df
# Out:
#                                      0              1   2   3   4          5  \
# 0    Club Social y Deportivo Colo-Colo     B. CortÃ©s  27  CL   1    Portero
# 1    Club Social y Deportivo Colo-Colo      J. Fierro  20  CL  25    Portero
# 2    Club Social y Deportivo Colo-Colo   O. CarabalÃ­  25  CL  12    Portero
# 3    Club Social y Deportivo Colo-Colo  B. GutiÃ©rrez  20  CL  13    Defensa
# 4    Club Social y Deportivo Colo-Colo  D. GutiÃ©rrez  19  CL   3    Defensa
# ..                                 ...            ...  ..  ..  ..        ...
# 479            Coquimbo Unido S.A.D.P.   I. Jeraldino  26  CL  19  Delantero
# 480            Coquimbo Unido S.A.D.P.    M. Alvarado  19  CL  34  Delantero
# 481            Coquimbo Unido S.A.D.P.       N. Gauna  30  AR  30  Delantero
# 482            Coquimbo Unido S.A.D.P.     R. FarfÃ¡n  31  CL  17  Delantero
# 483            Coquimbo Unido S.A.D.P.       G. Araya   -  CL  39
#
#        6   7
# 0    186  75
# 1    183  84
# 2    186  84
# 3    184  65
# 4    176  70
# ..   ...  ..
# 479  184  74
# 480    -   -
# 481  177  69
# 482  178  69
# 483    -   -
#
# [484 rows x 8 columns]

# %%
#Nombro columnas
plantillas_df.columns=['equipo','nombre','edad', 'nacionalidad','numero','posicion','altura','peso']

# %%
l = len(plantillas_df)
l
# Out:
# 484

# %%
#index= pd.Index(range(1,l+1))
#index

# %%
#establezco índice para evitar conflictos con la base de datos de destino
plantillas_df.set_index('equipo', inplace=True, )

# %%
#plantillas_df.drop(index)

# %%
# asigno una columna con el nombre de la liga a la cual pertenece cada jugador
#plantillas_df= plantillas_df.assign(liga= "")

# %%
plantillas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 484 entries, Club Social y Deportivo Colo-Colo to Coquimbo Unido S.A.D.P.
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        484 non-null    object
#  1   edad          484 non-null    object
#  2   nacionalidad  484 non-null    object
#  3   numero        484 non-null    object
#  4   posicion      484 non-null    object
#  5   altura        484 non-null    object
#  6   peso          484 non-null    object
# dtypes: object(7)
# memory usage: 30.2+ KB

# %%
plantillas_df
# Out:
#                                           nombre edad nacionalidad numero  \
# equipo
# Club Social y Deportivo Colo-Colo     B. CortÃ©s   27           CL      1
# Club Social y Deportivo Colo-Colo      J. Fierro   20           CL     25
# Club Social y Deportivo Colo-Colo   O. CarabalÃ­   25           CL     12
# Club Social y Deportivo Colo-Colo  B. GutiÃ©rrez   20           CL     13
# Club Social y Deportivo Colo-Colo  D. GutiÃ©rrez   19           CL      3
# ...                                          ...  ...          ...    ...
# Coquimbo Unido S.A.D.P.             I. Jeraldino   26           CL     19
# Coquimbo Unido S.A.D.P.              M. Alvarado   19           CL     34
# Coquimbo Unido S.A.D.P.                 N. Gauna   30           AR     30
# Coquimbo Unido S.A.D.P.               R. FarfÃ¡n   31           CL     17
# Coquimbo Unido S.A.D.P.                 G. Araya    -           CL     39
#
#                                     posicion altura peso
# equipo
# Club Social y Deportivo Colo-Colo    Portero    186   75
# Club Social y Deportivo Colo-Colo    Portero    183   84
# Club Social y Deportivo Colo-Colo    Portero    186   84
# Club Social y Deportivo Colo-Colo    Defensa    184   65
# Club Social y Deportivo Colo-Colo    Defensa    176   70
# ...                                      ...    ...  ...
# Coquimbo Unido S.A.D.P.            Delantero    184   74
# Coquimbo Unido S.A.D.P.            Delantero      -    -
# Coquimbo Unido S.A.D.P.            Delantero    177   69
# Coquimbo Unido S.A.D.P.            Delantero    178   69
# Coquimbo Unido S.A.D.P.                           -    -
#
# [484 rows x 7 columns]

# %%
#cambio tipo de datos
plantillas_df['altura'] = pd.to_numeric(plantillas_df['altura'], errors= 'coerce')
plantillas_df['peso'] = pd.to_numeric(plantillas_df['peso'], errors= 'coerce')
plantillas_df['edad'] = pd.to_numeric(plantillas_df['edad'], errors= 'coerce')

# %%
plantillas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 484 entries, Club Social y Deportivo Colo-Colo to Coquimbo Unido S.A.D.P.
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nombre        484 non-null    object
#  1   edad          476 non-null    float64
#  2   nacionalidad  484 non-null    object
#  3   numero        484 non-null    object
#  4   posicion      484 non-null    object
#  5   altura        401 non-null    float64
#  6   peso          379 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 30.2+ KB

# %%
#plantillas_df.drop(columns='liga', inplace=True)

# %%
#Exporto a Exel
with pd.ExcelWriter('plantillas-ligas-jugadores2022-2.xlsx', mode='a', engine ='openpyxl') as writer:
    plantillas_df.to_excel(writer, sheet_name= liga)

# %%
#Exporto a SQL

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\danie\anaconda3\lib\site-packages (2.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
cadena_conexion = 'postgres+psycopg2://postgres:2511@localhost:5432/analisis_futbol'

# %%
engine = create_engine(cadena_conexion)

# %%
plantillas_df.to_sql('jugadores',con=engine, if_exists= 'append', c)

# %%
pd1 = pd.read_excel('plantillas-ligas-jugadores2022-2.xlsx', encoding='utf8')

# %%
pd1
# Out:
#      Unnamed: 0                       equipo           nombre  edad  \
# 0             1                Club Nacional  Federico GÃ³mez  21.0
# 1             2                Club Nacional    R. RodrÃ­guez  35.0
# 2             3                Club Nacional         S. Rojas  26.0
# 3             4                Club Nacional       A. Aguilar  21.0
# 4             5                Club Nacional       B. Cabrera  25.0
# ..          ...                          ...              ...   ...
# 453         454  12 de octubre Football Club     L. GonzÃ¡lez  24.0
# 454         455  12 de octubre Football Club     M. Batallini  31.0
# 455         456  12 de octubre Football Club      N. Sanabria  28.0
# 456         457  12 de octubre Football Club        R. AcuÃ±a  29.0
# 457         458  12 de octubre Football Club          K. Arce   NaN
#
#     nacionalidad  numero_jugador   posicion  altura  peso
# 0             PY            40.0    Portero   173.0  72.0
# 1             PY             1.0    Portero   193.0  92.0
# 2             PY            30.0    Portero   180.0  78.0
# 3             PY             NaN    Defensa     NaN   NaN
# 4             AR            28.0    Defensa     NaN   NaN
# ..           ...             ...        ...     ...   ...
# 453           PY            20.0  Delantero   180.0  73.0
# 454           AR            32.0  Delantero   174.0  78.0
# 455           PY             7.0  Delantero     NaN   NaN
# 456           PY            37.0  Delantero     NaN   NaN
# 457           PY            34.0        NaN     NaN   NaN
#
# [458 rows x 9 columns]
